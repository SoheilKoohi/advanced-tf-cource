# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import io
from PIL import Image

from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, LearningRateScheduler, ModelCheckpoint, CSVLogger, ReduceLROnPlateau
# %load_ext tensorboard

import os
import matplotlib.pylab as plt
import numpy as np
import math
import datetime
import pandas as pd

print("Version: ", tf.__version__)
tf.get_logger().setLevel('INFO')
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Version:  2.8.2

# %% [markdown]
# ## Download and prepare the horses or humans dataset

# %%
ds, info = tfds.load('horses_or_humans', as_supervised=True, with_info=True, split=['train[:80%]', 'train[80%:]', 'test'])

(train_ds, validation_ds, test_ds) = ds

num_examples = info.splits['train'].num_examples
num_classes = info.features['label'].num_classes
# Out:
# Downloading and preparing dataset 153.59 MiB (download: 153.59 MiB, generated: Unknown size, total: 153.59 MiB) to ~/tensorflow_datasets/horses_or_humans/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/1027 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/horses_or_humans/3.0.0.incomplete91JX64/horses_or_humans-train.tfrecord*...:  …
# Generating test examples...:   0%|          | 0/256 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/horses_or_humans/3.0.0.incomplete91JX64/horses_or_humans-test.tfrecord*...:   …
# Dataset horses_or_humans downloaded and prepared to ~/tensorflow_datasets/horses_or_humans/3.0.0. Subsequent calls will reuse this data.

# %%
print(num_examples)
print(num_classes)
# Out:
# 1027
# 2

# %%
IMAGE_SIZE = (150, 150)

# %%
def preprocess_image(image, label):
  image = tf.image.resize(image, IMAGE_SIZE) / 255.0
  return  image, label

# %%
BATCH_SIZE = 32
train_batches = train_ds.shuffle(num_examples // 4).map(preprocess_image).batch(BATCH_SIZE).prefetch(1)
validation_batches = validation_ds.map(preprocess_image).batch(BATCH_SIZE).prefetch(1)
test_batches = test_ds.map(preprocess_image).batch(1)

# %%
image_batch, label_batch = next(iter(train_batches.take(1)))


image_batch.shape, label_batch.shape
# Out:
# (TensorShape([32, 150, 150, 3]), TensorShape([32]))

# %% [markdown]
# ## Create Model

# %%
def build_model(dense_units, input_shape=IMAGE_SIZE + (3,)):
  model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=input_shape),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(dense_units, activation='relu'),
      tf.keras.layers.Dense(2, activation='softmax')
  ])
  return model

# %% [markdown]
# ## TensorBoard Callback

# %%
# !rm -rf logs

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir,
                                                      #histogram_freq=1,
                                                      #update_freq=1,
                                                      )

model.fit(train_batches, 
          epochs=10, 
          validation_data=validation_batches, 
          callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 26/26 [==============================] - 17s 557ms/step - loss: 0.6750 - accuracy: 0.5645 - val_loss: 0.6545 - val_accuracy: 0.6293
# Epoch 2/10
# 26/26 [==============================] - 11s 438ms/step - loss: 0.6294 - accuracy: 0.6752 - val_loss: 0.6149 - val_accuracy: 0.6634
# Epoch 3/10
# 26/26 [==============================] - 11s 421ms/step - loss: 0.5797 - accuracy: 0.7117 - val_loss: 0.5810 - val_accuracy: 0.6634
# Epoch 4/10
# 26/26 [==============================] - 11s 440ms/step - loss: 0.5369 - accuracy: 0.7287 - val_loss: 0.5178 - val_accuracy: 0.7561
# Epoch 5/10
# 26/26 [==============================] - 12s 454ms/step - loss: 0.4476 - accuracy: 0.8321 - val_loss: 0.5778 - val_accuracy: 0.6488
# Epoch 6/10
# 26/26 [==============================] - 12s 444ms/step - loss: 0.3974 - accuracy: 0.8491 - val_loss: 0.3589 - val_accuracy: 0.8878
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-96d9260bedb3> in <module>
#      14           epochs=10,
#      15           validation_data=validation_batches,
# ---> 16           callbacks=[tensorboard_callback])
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1371       logs = None
#    1372       for epoch, iterator in data_handler.enumerate_epochs():
# -> 1373         self.reset_metrics()
#    1374         callbacks.on_epoch_begin(epoch)
#    1375         with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ## Saving Checkpoints

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=5, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.h5', verbose=1),
          ])

# %%
# !ls .

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=1, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[ModelCheckpoint('saved_model', verbose=1)
          ])

# %%
 ! ls .

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=10, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[ModelCheckpoint('model.h5', save_weights_only=True, save_best_only=True, monitor="val_loss", mode="min", verbose=1)
          ])

# %% [markdown]
# ## Early Stopping

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=50, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[EarlyStopping(
              patience=3,
              min_delta=0.05,
              baseline=0.8,
              mode='min',
              monitor='val_loss',
              restore_best_weights=True,
              verbose=1)
          ])

# %% [markdown]
# ## Learning Rate Scheduler

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
def step_decay(epoch):
	initial_lr = 0.01
	drop = 0.5
	epochs_drop = 1
	lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lr

model.fit(train_batches, 
          epochs=5, 
          validation_data=validation_batches, 
          callbacks=[LearningRateScheduler(step_decay, verbose=1),
                    TensorBoard(log_dir='./log_dir')])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.005.
# Epoch 1/5
# 26/26 [==============================] - 12s 453ms/step - loss: 0.6811 - accuracy: 0.5633 - val_loss: 0.6697 - val_accuracy: 0.7805 - lr: 0.0050
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 2/5
# 26/26 [==============================] - 11s 425ms/step - loss: 0.6592 - accuracy: 0.6655 - val_loss: 0.6674 - val_accuracy: 0.5756 - lr: 0.0025
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 3/5
# 26/26 [==============================] - 11s 439ms/step - loss: 0.6475 - accuracy: 0.6569 - val_loss: 0.6628 - val_accuracy: 0.6049 - lr: 0.0012
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 4/5
# 26/26 [==============================] - 11s 440ms/step - loss: 0.6410 - accuracy: 0.6922 - val_loss: 0.6629 - val_accuracy: 0.5659 - lr: 6.2500e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 5/5
# 26/26 [==============================] - 11s 440ms/step - loss: 0.6385 - accuracy: 0.6557 - val_loss: 0.6597 - val_accuracy: 0.5951 - lr: 3.1250e-04

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
def exp_decay_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

model.fit(train_batches, 
          epochs=15, 
          validation_data=validation_batches, 
          callbacks=[LearningRateScheduler(exp_decay_scheduler, verbose=1),
                    TensorBoard(log_dir='./log_dir')])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 1/15
# 26/26 [==============================] - 11s 421ms/step - loss: 0.6736 - accuracy: 0.6022 - val_loss: 0.6528 - val_accuracy: 0.6829 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 2/15
# 26/26 [==============================] - 11s 440ms/step - loss: 0.6385 - accuracy: 0.6594 - val_loss: 0.6951 - val_accuracy: 0.4829 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 3/15
# 26/26 [==============================] - 11s 421ms/step - loss: 0.5756 - accuracy: 0.7518 - val_loss: 0.5759 - val_accuracy: 0.6927 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 4/15
# 26/26 [==============================] - 11s 422ms/step - loss: 0.5339 - accuracy: 0.7494 - val_loss: 0.4735 - val_accuracy: 0.8244 - lr: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 5/15
# 26/26 [==============================] - 11s 417ms/step - loss: 0.4578 - accuracy: 0.8236 - val_loss: 0.4441 - val_accuracy: 0.8439 - lr: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 6/15
# 26/26 [==============================] - 11s 438ms/step - loss: 0.3962 - accuracy: 0.8601 - val_loss: 0.3657 - val_accuracy: 0.8878 - lr: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 7/15
# 26/26 [==============================] - 11s 439ms/step - loss: 0.3027 - accuracy: 0.9075 - val_loss: 0.3955 - val_accuracy: 0.8341 - lr: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 8/15
# 26/26 [==============================] - 11s 441ms/step - loss: 0.2714 - accuracy: 0.9027 - val_loss: 0.2034 - val_accuracy: 0.9415 - lr: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 9/15
# 26/26 [==============================] - 11s 441ms/step - loss: 0.1948 - accuracy: 0.9489 - val_loss: 0.1751 - val_accuracy: 0.9512 - lr: 0.0100
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 10/15
# 26/26 [==============================] - 11s 441ms/step - loss: 0.1540 - accuracy: 0.9635 - val_loss: 0.1705 - val_accuracy: 0.9415 - lr: 0.0100
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.009048374369740486.
# Epoch 11/15
# 26/26 [==============================] - 11s 421ms/step - loss: 0.1288 - accuracy: 0.9659 - val_loss: 0.1060 - val_accuracy: 0.9610 - lr: 0.0090
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.008187307976186275.
# Epoch 12/15
# 26/26 [==============================] - 11s 439ms/step - loss: 0.1213 - accuracy: 0.9684 - val_loss: 0.0923 - val_accuracy: 0.9805 - lr: 0.0082
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.007408182602375746.
# Epoch 13/15
# 26/26 [==============================] - 11s 440ms/step - loss: 0.0936 - accuracy: 0.9805 - val_loss: 0.0813 - val_accuracy: 0.9854 - lr: 0.0074
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.006703200750052929.
# Epoch 14/15
# 26/26 [==============================] - 11s 421ms/step - loss: 0.0789 - accuracy: 0.9842 - val_loss: 0.0721 - val_accuracy: 0.9854 - lr: 0.0067
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.006065306719392538.
# Epoch 15/15
# 26/26 [==============================] - 11s 422ms/step - loss: 0.0708 - accuracy: 0.9854 - val_loss: 0.0788 - val_accuracy: 0.9707 - lr: 0.0061

# %% [markdown]
# ## Custom Callbacks

# %% [markdown]
# Now, define a simple custom callback that logs:
#
# - When `fit`/`evaluate`/`predict` starts & ends
# - When each epoch starts & ends
# - When each training batch starts & ends
# - When each evaluation (test) batch starts & ends
# - When each inference (prediction) batch starts & ends

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        keys = list(logs.keys())
        print("Starting training; got log keys: {}".format(keys))

    def on_train_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop training; got log keys: {}".format(keys))

    def on_epoch_begin(self, epoch, logs=None):
        keys = list(logs.keys())
        print("Start epoch {} of training; got log keys: {}".format(epoch, keys))

    def on_epoch_end(self, epoch, logs=None):
        keys = list(logs.keys())
        print("End epoch {} of training; got log keys: {}".format(epoch, keys))

    def on_test_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start testing; got log keys: {}".format(keys))

    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop testing; got log keys: {}".format(keys))

    def on_predict_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start predicting; got log keys: {}".format(keys))

    def on_predict_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop predicting; got log keys: {}".format(keys))

    def on_train_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Training: start of batch {}; got log keys: {}".format(batch, keys))

    def on_train_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Training: end of batch {}; got log keys: {}".format(batch, keys))

    def on_test_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Evaluating: start of batch {}; got log keys: {}".format(batch, keys))

    def on_test_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Evaluating: end of batch {}; got log keys: {}".format(batch, keys))

    def on_predict_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Predicting: start of batch {}; got log keys: {}".format(batch, keys))

    def on_predict_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Predicting: end of batch {}; got log keys: {}".format(batch, keys))

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
model.fit(train_batches, 
          epochs=2, 
          validation_data=validation_batches, 
          verbose=0,
          callbacks=[CustomCallback()])
# Out:
# Starting training; got log keys: []
# Start epoch 0 of training; got log keys: []
# ...Training: start of batch 0; got log keys: []
# ...Training: end of batch 0; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 1; got log keys: []
# ...Training: end of batch 1; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 2; got log keys: []
# ...Training: end of batch 2; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 3; got log keys: []
# ...Training: end of batch 3; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 4; got log keys: []
# ...Training: end of batch 4; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 5; got log keys: []
# ...Training: end of batch 5; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 6; got log keys: []
# ...Training: end of batch 6; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 7; got log keys: []
# ...Training: end of batch 7; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 8; got log keys: []
# ...Training: end of batch 8; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 9; got log keys: []
# ...Training: end of batch 9; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 10; got log keys: []
# ...Training: end of batch 10; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 11; got log keys: []
# ...Training: end of batch 11; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 12; got log keys: []
# ...Training: end of batch 12; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 13; got log keys: []
# ...Training: end of batch 13; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 14; got log keys: []
# ...Training: end of batch 14; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 15; got log keys: []
# ...Training: end of batch 15; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 16; got log keys: []
# ...Training: end of batch 16; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 17; got log keys: []
# ...Training: end of batch 17; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 18; got log keys: []
# ...Training: end of batch 18; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 19; got log keys: []
# ...Training: end of batch 19; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 20; got log keys: []
# ...Training: end of batch 20; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 21; got log keys: []
# ...Training: end of batch 21; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 22; got log keys: []
# ...Training: end of batch 22; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 23; got log keys: []
# ...Training: end of batch 23; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 24; got log keys: []
# ...Training: end of batch 24; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 25; got log keys: []
# ...Training: end of batch 25; got log keys: ['loss', 'accuracy']
# Start testing; got log keys: []
# ...Evaluating: start of batch 0; got log keys: []
# ...Evaluating: end of batch 0; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 1; got log keys: []
# ...Evaluating: end of batch 1; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 2; got log keys: []
# ...Evaluating: end of batch 2; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 3; got log keys: []
# ...Evaluating: end of batch 3; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 4; got log keys: []
# ...Evaluating: end of batch 4; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 5; got log keys: []
# ...Evaluating: end of batch 5; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 6; got log keys: []
# ...Evaluating: end of batch 6; got log keys: ['loss', 'accuracy']
# Stop testing; got log keys: ['loss', 'accuracy']
# End epoch 0 of training; got log keys: ['loss', 'accuracy', 'val_loss', 'val_accuracy']
# Start epoch 1 of training; got log keys: []
# ...Training: start of batch 0; got log keys: []
# ...Training: end of batch 0; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 1; got log keys: []
# ...Training: end of batch 1; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 2; got log keys: []
# ...Training: end of batch 2; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 3; got log keys: []
# ...Training: end of batch 3; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 4; got log keys: []
# ...Training: end of batch 4; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 5; got log keys: []
# ...Training: end of batch 5; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 6; got log keys: []
# ...Training: end of batch 6; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 7; got log keys: []
# ...Training: end of batch 7; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 8; got log keys: []
# ...Training: end of batch 8; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 9; got log keys: []
# ...Training: end of batch 9; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 10; got log keys: []
# ...Training: end of batch 10; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 11; got log keys: []
# ...Training: end of batch 11; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 12; got log keys: []
# ...Training: end of batch 12; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 13; got log keys: []
# ...Training: end of batch 13; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 14; got log keys: []
# ...Training: end of batch 14; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 15; got log keys: []
# ...Training: end of batch 15; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 16; got log keys: []
# ...Training: end of batch 16; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 17; got log keys: []
# ...Training: end of batch 17; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 18; got log keys: []
# ...Training: end of batch 18; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 19; got log keys: []
# ...Training: end of batch 19; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 20; got log keys: []
# ...Training: end of batch 20; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 21; got log keys: []
# ...Training: end of batch 21; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 22; got log keys: []
# ...Training: end of batch 22; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 23; got log keys: []
# ...Training: end of batch 23; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 24; got log keys: []
# ...Training: end of batch 24; got log keys: ['loss', 'accuracy']
# ...Training: start of batch 25; got log keys: []
# ...Training: end of batch 25; got log keys: ['loss', 'accuracy']
# Start testing; got log keys: []
# ...Evaluating: start of batch 0; got log keys: []
# ...Evaluating: end of batch 0; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 1; got log keys: []
# ...Evaluating: end of batch 1; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 2; got log keys: []
# ...Evaluating: end of batch 2; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 3; got log keys: []
# ...Evaluating: end of batch 3; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 4; got log keys: []
# ...Evaluating: end of batch 4; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 5; got log keys: []
# ...Evaluating: end of batch 5; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 6; got log keys: []
# ...Evaluating: end of batch 6; got log keys: ['loss', 'accuracy']
# Stop testing; got log keys: ['loss', 'accuracy']
# End epoch 1 of training; got log keys: ['loss', 'accuracy', 'val_loss', 'val_accuracy']
# Stop training; got log keys: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %%
res = model.evaluate(
    test_batches, verbose=0, callbacks=[CustomCallback()]
)

res = model.predict(test_batches, batch_size=128, callbacks=[CustomCallback()])
# Out:
# Start testing; got log keys: []
# ...Evaluating: start of batch 0; got log keys: []
# ...Evaluating: end of batch 0; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 1; got log keys: []
# ...Evaluating: end of batch 1; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 2; got log keys: []
# ...Evaluating: end of batch 2; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 3; got log keys: []
# ...Evaluating: end of batch 3; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 4; got log keys: []
# ...Evaluating: end of batch 4; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 5; got log keys: []
# ...Evaluating: end of batch 5; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 6; got log keys: []
# ...Evaluating: end of batch 6; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 7; got log keys: []
# ...Evaluating: end of batch 7; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 8; got log keys: []
# ...Evaluating: end of batch 8; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 9; got log keys: []
# ...Evaluating: end of batch 9; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 10; got log keys: []
# ...Evaluating: end of batch 10; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 11; got log keys: []
# ...Evaluating: end of batch 11; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 12; got log keys: []
# ...Evaluating: end of batch 12; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 13; got log keys: []
# ...Evaluating: end of batch 13; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 14; got log keys: []
# ...Evaluating: end of batch 14; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 15; got log keys: []
# ...Evaluating: end of batch 15; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 16; got log keys: []
# ...Evaluating: end of batch 16; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 17; got log keys: []
# ...Evaluating: end of batch 17; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 18; got log keys: []
# ...Evaluating: end of batch 18; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 19; got log keys: []
# ...Evaluating: end of batch 19; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 20; got log keys: []
# ...Evaluating: end of batch 20; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 21; got log keys: []
# ...Evaluating: end of batch 21; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 22; got log keys: []
# ...Evaluating: end of batch 22; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 23; got log keys: []
# ...Evaluating: end of batch 23; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 24; got log keys: []
# ...Evaluating: end of batch 24; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 25; got log keys: []
# ...Evaluating: end of batch 25; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 26; got log keys: []
# ...Evaluating: end of batch 26; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 27; got log keys: []
# ...Evaluating: end of batch 27; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 28; got log keys: []
# ...Evaluating: end of batch 28; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 29; got log keys: []
# ...Evaluating: end of batch 29; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 30; got log keys: []
# ...Evaluating: end of batch 30; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 31; got log keys: []
# ...Evaluating: end of batch 31; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 32; got log keys: []
# ...Evaluating: end of batch 32; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 33; got log keys: []
# ...Evaluating: end of batch 33; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 34; got log keys: []
# ...Evaluating: end of batch 34; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 35; got log keys: []
# ...Evaluating: end of batch 35; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 36; got log keys: []
# ...Evaluating: end of batch 36; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 37; got log keys: []
# ...Evaluating: end of batch 37; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 38; got log keys: []
# ...Evaluating: end of batch 38; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 39; got log keys: []
# ...Evaluating: end of batch 39; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 40; got log keys: []
# ...Evaluating: end of batch 40; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 41; got log keys: []
# ...Evaluating: end of batch 41; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 42; got log keys: []
# ...Evaluating: end of batch 42; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 43; got log keys: []
# ...Evaluating: end of batch 43; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 44; got log keys: []
# ...Evaluating: end of batch 44; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 45; got log keys: []
# ...Evaluating: end of batch 45; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 46; got log keys: []
# ...Evaluating: end of batch 46; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 47; got log keys: []
# ...Evaluating: end of batch 47; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 48; got log keys: []
# ...Evaluating: end of batch 48; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 49; got log keys: []
# ...Evaluating: end of batch 49; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 50; got log keys: []
# ...Evaluating: end of batch 50; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 51; got log keys: []
# ...Evaluating: end of batch 51; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 52; got log keys: []
# ...Evaluating: end of batch 52; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 53; got log keys: []
# ...Evaluating: end of batch 53; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 54; got log keys: []
# ...Evaluating: end of batch 54; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 55; got log keys: []
# ...Evaluating: end of batch 55; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 56; got log keys: []
# ...Evaluating: end of batch 56; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 57; got log keys: []
# ...Evaluating: end of batch 57; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 58; got log keys: []
# ...Evaluating: end of batch 58; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 59; got log keys: []
# ...Evaluating: end of batch 59; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 60; got log keys: []
# ...Evaluating: end of batch 60; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 61; got log keys: []
# ...Evaluating: end of batch 61; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 62; got log keys: []
# ...Evaluating: end of batch 62; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 63; got log keys: []
# ...Evaluating: end of batch 63; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 64; got log keys: []
# ...Evaluating: end of batch 64; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 65; got log keys: []
# ...Evaluating: end of batch 65; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 66; got log keys: []
# ...Evaluating: end of batch 66; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 67; got log keys: []
# ...Evaluating: end of batch 67; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 68; got log keys: []
# ...Evaluating: end of batch 68; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 69; got log keys: []
# ...Evaluating: end of batch 69; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 70; got log keys: []
# ...Evaluating: end of batch 70; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 71; got log keys: []
# ...Evaluating: end of batch 71; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 72; got log keys: []
# ...Evaluating: end of batch 72; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 73; got log keys: []
# ...Evaluating: end of batch 73; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 74; got log keys: []
# ...Evaluating: end of batch 74; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 75; got log keys: []
# ...Evaluating: end of batch 75; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 76; got log keys: []
# ...Evaluating: end of batch 76; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 77; got log keys: []
# ...Evaluating: end of batch 77; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 78; got log keys: []
# ...Evaluating: end of batch 78; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 79; got log keys: []
# ...Evaluating: end of batch 79; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 80; got log keys: []
# ...Evaluating: end of batch 80; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 81; got log keys: []
# ...Evaluating: end of batch 81; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 82; got log keys: []
# ...Evaluating: end of batch 82; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 83; got log keys: []
# ...Evaluating: end of batch 83; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 84; got log keys: []
# ...Evaluating: end of batch 84; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 85; got log keys: []
# ...Evaluating: end of batch 85; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 86; got log keys: []
# ...Evaluating: end of batch 86; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 87; got log keys: []
# ...Evaluating: end of batch 87; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 88; got log keys: []
# ...Evaluating: end of batch 88; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 89; got log keys: []
# ...Evaluating: end of batch 89; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 90; got log keys: []
# ...Evaluating: end of batch 90; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 91; got log keys: []
# ...Evaluating: end of batch 91; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 92; got log keys: []
# ...Evaluating: end of batch 92; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 93; got log keys: []
# ...Evaluating: end of batch 93; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 94; got log keys: []
# ...Evaluating: end of batch 94; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 95; got log keys: []
# ...Evaluating: end of batch 95; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 96; got log keys: []
# ...Evaluating: end of batch 96; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 97; got log keys: []
# ...Evaluating: end of batch 97; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 98; got log keys: []
# ...Evaluating: end of batch 98; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 99; got log keys: []
# ...Evaluating: end of batch 99; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 100; got log keys: []
# ...Evaluating: end of batch 100; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 101; got log keys: []
# ...Evaluating: end of batch 101; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 102; got log keys: []
# ...Evaluating: end of batch 102; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 103; got log keys: []
# ...Evaluating: end of batch 103; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 104; got log keys: []
# ...Evaluating: end of batch 104; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 105; got log keys: []
# ...Evaluating: end of batch 105; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 106; got log keys: []
# ...Evaluating: end of batch 106; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 107; got log keys: []
# ...Evaluating: end of batch 107; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 108; got log keys: []
# ...Evaluating: end of batch 108; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 109; got log keys: []
# ...Evaluating: end of batch 109; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 110; got log keys: []
# ...Evaluating: end of batch 110; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 111; got log keys: []
# ...Evaluating: end of batch 111; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 112; got log keys: []
# ...Evaluating: end of batch 112; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 113; got log keys: []
# ...Evaluating: end of batch 113; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 114; got log keys: []
# ...Evaluating: end of batch 114; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 115; got log keys: []
# ...Evaluating: end of batch 115; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 116; got log keys: []
# ...Evaluating: end of batch 116; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 117; got log keys: []
# ...Evaluating: end of batch 117; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 118; got log keys: []
# ...Evaluating: end of batch 118; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 119; got log keys: []
# ...Evaluating: end of batch 119; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 120; got log keys: []
# ...Evaluating: end of batch 120; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 121; got log keys: []
# ...Evaluating: end of batch 121; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 122; got log keys: []
# ...Evaluating: end of batch 122; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 123; got log keys: []
# ...Evaluating: end of batch 123; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 124; got log keys: []
# ...Evaluating: end of batch 124; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 125; got log keys: []
# ...Evaluating: end of batch 125; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 126; got log keys: []
# ...Evaluating: end of batch 126; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 127; got log keys: []
# ...Evaluating: end of batch 127; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 128; got log keys: []
# ...Evaluating: end of batch 128; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 129; got log keys: []
# ...Evaluating: end of batch 129; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 130; got log keys: []
# ...Evaluating: end of batch 130; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 131; got log keys: []
# ...Evaluating: end of batch 131; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 132; got log keys: []
# ...Evaluating: end of batch 132; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 133; got log keys: []
# ...Evaluating: end of batch 133; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 134; got log keys: []
# ...Evaluating: end of batch 134; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 135; got log keys: []
# ...Evaluating: end of batch 135; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 136; got log keys: []
# ...Evaluating: end of batch 136; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 137; got log keys: []
# ...Evaluating: end of batch 137; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 138; got log keys: []
# ...Evaluating: end of batch 138; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 139; got log keys: []
# ...Evaluating: end of batch 139; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 140; got log keys: []
# ...Evaluating: end of batch 140; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 141; got log keys: []
# ...Evaluating: end of batch 141; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 142; got log keys: []
# ...Evaluating: end of batch 142; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 143; got log keys: []
# ...Evaluating: end of batch 143; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 144; got log keys: []
# ...Evaluating: end of batch 144; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 145; got log keys: []
# ...Evaluating: end of batch 145; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 146; got log keys: []
# ...Evaluating: end of batch 146; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 147; got log keys: []
# ...Evaluating: end of batch 147; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 148; got log keys: []
# ...Evaluating: end of batch 148; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 149; got log keys: []
# ...Evaluating: end of batch 149; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 150; got log keys: []
# ...Evaluating: end of batch 150; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 151; got log keys: []
# ...Evaluating: end of batch 151; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 152; got log keys: []
# ...Evaluating: end of batch 152; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 153; got log keys: []
# ...Evaluating: end of batch 153; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 154; got log keys: []
# ...Evaluating: end of batch 154; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 155; got log keys: []
# ...Evaluating: end of batch 155; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 156; got log keys: []
# ...Evaluating: end of batch 156; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 157; got log keys: []
# ...Evaluating: end of batch 157; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 158; got log keys: []
# ...Evaluating: end of batch 158; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 159; got log keys: []
# ...Evaluating: end of batch 159; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 160; got log keys: []
# ...Evaluating: end of batch 160; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 161; got log keys: []
# ...Evaluating: end of batch 161; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 162; got log keys: []
# ...Evaluating: end of batch 162; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 163; got log keys: []
# ...Evaluating: end of batch 163; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 164; got log keys: []
# ...Evaluating: end of batch 164; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 165; got log keys: []
# ...Evaluating: end of batch 165; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 166; got log keys: []
# ...Evaluating: end of batch 166; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 167; got log keys: []
# ...Evaluating: end of batch 167; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 168; got log keys: []
# ...Evaluating: end of batch 168; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 169; got log keys: []
# ...Evaluating: end of batch 169; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 170; got log keys: []
# ...Evaluating: end of batch 170; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 171; got log keys: []
# ...Evaluating: end of batch 171; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 172; got log keys: []
# ...Evaluating: end of batch 172; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 173; got log keys: []
# ...Evaluating: end of batch 173; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 174; got log keys: []
# ...Evaluating: end of batch 174; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 175; got log keys: []
# ...Evaluating: end of batch 175; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 176; got log keys: []
# ...Evaluating: end of batch 176; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 177; got log keys: []
# ...Evaluating: end of batch 177; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 178; got log keys: []
# ...Evaluating: end of batch 178; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 179; got log keys: []
# ...Evaluating: end of batch 179; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 180; got log keys: []
# ...Evaluating: end of batch 180; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 181; got log keys: []
# ...Evaluating: end of batch 181; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 182; got log keys: []
# ...Evaluating: end of batch 182; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 183; got log keys: []
# ...Evaluating: end of batch 183; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 184; got log keys: []
# ...Evaluating: end of batch 184; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 185; got log keys: []
# ...Evaluating: end of batch 185; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 186; got log keys: []
# ...Evaluating: end of batch 186; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 187; got log keys: []
# ...Evaluating: end of batch 187; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 188; got log keys: []
# ...Evaluating: end of batch 188; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 189; got log keys: []
# ...Evaluating: end of batch 189; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 190; got log keys: []
# ...Evaluating: end of batch 190; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 191; got log keys: []
# ...Evaluating: end of batch 191; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 192; got log keys: []
# ...Evaluating: end of batch 192; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 193; got log keys: []
# ...Evaluating: end of batch 193; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 194; got log keys: []
# ...Evaluating: end of batch 194; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 195; got log keys: []
# ...Evaluating: end of batch 195; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 196; got log keys: []
# ...Evaluating: end of batch 196; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 197; got log keys: []
# ...Evaluating: end of batch 197; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 198; got log keys: []
# ...Evaluating: end of batch 198; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 199; got log keys: []
# ...Evaluating: end of batch 199; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 200; got log keys: []
# ...Evaluating: end of batch 200; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 201; got log keys: []
# ...Evaluating: end of batch 201; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 202; got log keys: []
# ...Evaluating: end of batch 202; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 203; got log keys: []
# ...Evaluating: end of batch 203; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 204; got log keys: []
# ...Evaluating: end of batch 204; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 205; got log keys: []
# ...Evaluating: end of batch 205; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 206; got log keys: []
# ...Evaluating: end of batch 206; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 207; got log keys: []
# ...Evaluating: end of batch 207; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 208; got log keys: []
# ...Evaluating: end of batch 208; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 209; got log keys: []
# ...Evaluating: end of batch 209; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 210; got log keys: []
# ...Evaluating: end of batch 210; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 211; got log keys: []
# ...Evaluating: end of batch 211; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 212; got log keys: []
# ...Evaluating: end of batch 212; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 213; got log keys: []
# ...Evaluating: end of batch 213; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 214; got log keys: []
# ...Evaluating: end of batch 214; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 215; got log keys: []
# ...Evaluating: end of batch 215; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 216; got log keys: []
# ...Evaluating: end of batch 216; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 217; got log keys: []
# ...Evaluating: end of batch 217; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 218; got log keys: []
# ...Evaluating: end of batch 218; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 219; got log keys: []
# ...Evaluating: end of batch 219; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 220; got log keys: []
# ...Evaluating: end of batch 220; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 221; got log keys: []
# ...Evaluating: end of batch 221; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 222; got log keys: []
# ...Evaluating: end of batch 222; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 223; got log keys: []
# ...Evaluating: end of batch 223; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 224; got log keys: []
# ...Evaluating: end of batch 224; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 225; got log keys: []
# ...Evaluating: end of batch 225; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 226; got log keys: []
# ...Evaluating: end of batch 226; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 227; got log keys: []
# ...Evaluating: end of batch 227; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 228; got log keys: []
# ...Evaluating: end of batch 228; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 229; got log keys: []
# ...Evaluating: end of batch 229; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 230; got log keys: []
# ...Evaluating: end of batch 230; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 231; got log keys: []
# ...Evaluating: end of batch 231; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 232; got log keys: []
# ...Evaluating: end of batch 232; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 233; got log keys: []
# ...Evaluating: end of batch 233; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 234; got log keys: []
# ...Evaluating: end of batch 234; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 235; got log keys: []
# ...Evaluating: end of batch 235; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 236; got log keys: []
# ...Evaluating: end of batch 236; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 237; got log keys: []
# ...Evaluating: end of batch 237; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 238; got log keys: []
# ...Evaluating: end of batch 238; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 239; got log keys: []
# ...Evaluating: end of batch 239; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 240; got log keys: []
# ...Evaluating: end of batch 240; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 241; got log keys: []
# ...Evaluating: end of batch 241; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 242; got log keys: []
# ...Evaluating: end of batch 242; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 243; got log keys: []
# ...Evaluating: end of batch 243; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 244; got log keys: []
# ...Evaluating: end of batch 244; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 245; got log keys: []
# ...Evaluating: end of batch 245; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 246; got log keys: []
# ...Evaluating: end of batch 246; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 247; got log keys: []
# ...Evaluating: end of batch 247; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 248; got log keys: []
# ...Evaluating: end of batch 248; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 249; got log keys: []
# ...Evaluating: end of batch 249; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 250; got log keys: []
# ...Evaluating: end of batch 250; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 251; got log keys: []
# ...Evaluating: end of batch 251; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 252; got log keys: []
# ...Evaluating: end of batch 252; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 253; got log keys: []
# ...Evaluating: end of batch 253; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 254; got log keys: []
# ...Evaluating: end of batch 254; got log keys: ['loss', 'accuracy']
# ...Evaluating: start of batch 255; got log keys: []
# ...Evaluating: end of batch 255; got log keys: ['loss', 'accuracy']
# Stop testing; got log keys: ['loss', 'accuracy']
# Start predicting; got log keys: []
# ...Predicting: start of batch 0; got log keys: []
# ...Predicting: end of batch 0; got log keys: ['outputs']
# ...Predicting: start of batch 1; got log keys: []
# ...Predicting: end of batch 1; got log keys: ['outputs']
# ...Predicting: start of batch 2; got log keys: []
# ...Predicting: end of batch 2; got log keys: ['outputs']
# ...Predicting: start of batch 3; got log keys: []
# ...Predicting: end of batch 3; got log keys: ['outputs']
# ...Predicting: start of batch 4; got log keys: []
# ...Predicting: end of batch 4; got log keys: ['outputs']
# ...Predicting: start of batch 5; got log keys: []
# ...Predicting: end of batch 5; got log keys: ['outputs']
# ...Predicting: start of batch 6; got log keys: []
# ...Predicting: end of batch 6; got log keys: ['outputs']
# ...Predicting: start of batch 7; got log keys: []
# ...Predicting: end of batch 7; got log keys: ['outputs']
# ...Predicting: start of batch 8; got log keys: []
# ...Predicting: end of batch 8; got log keys: ['outputs']
# ...Predicting: start of batch 9; got log keys: []
# ...Predicting: end of batch 9; got log keys: ['outputs']
# ...Predicting: start of batch 10; got log keys: []
# ...Predicting: end of batch 10; got log keys: ['outputs']
# ...Predicting: start of batch 11; got log keys: []
# ...Predicting: end of batch 11; got log keys: ['outputs']
# ...Predicting: start of batch 12; got log keys: []
# ...Predicting: end of batch 12; got log keys: ['outputs']
# ...Predicting: start of batch 13; got log keys: []
# ...Predicting: end of batch 13; got log keys: ['outputs']
# ...Predicting: start of batch 14; got log keys: []
# ...Predicting: end of batch 14; got log keys: ['outputs']
# ...Predicting: start of batch 15; got log keys: []
# ...Predicting: end of batch 15; got log keys: ['outputs']
# ...Predicting: start of batch 16; got log keys: []
# ...Predicting: end of batch 16; got log keys: ['outputs']
# ...Predicting: start of batch 17; got log keys: []
# ...Predicting: end of batch 17; got log keys: ['outputs']
# ...Predicting: start of batch 18; got log keys: []
# ...Predicting: end of batch 18; got log keys: ['outputs']
# ...Predicting: start of batch 19; got log keys: []
# ...Predicting: end of batch 19; got log keys: ['outputs']
# ...Predicting: start of batch 20; got log keys: []
# ...Predicting: end of batch 20; got log keys: ['outputs']
# ...Predicting: start of batch 21; got log keys: []
# ...Predicting: end of batch 21; got log keys: ['outputs']
# ...Predicting: start of batch 22; got log keys: []
# ...Predicting: end of batch 22; got log keys: ['outputs']
# ...Predicting: start of batch 23; got log keys: []
# ...Predicting: end of batch 23; got log keys: ['outputs']
# ...Predicting: start of batch 24; got log keys: []
# ...Predicting: end of batch 24; got log keys: ['outputs']
# ...Predicting: start of batch 25; got log keys: []
# ...Predicting: end of batch 25; got log keys: ['outputs']
# ...Predicting: start of batch 26; got log keys: []
# ...Predicting: end of batch 26; got log keys: ['outputs']
# ...Predicting: start of batch 27; got log keys: []
# ...Predicting: end of batch 27; got log keys: ['outputs']
# ...Predicting: start of batch 28; got log keys: []
# ...Predicting: end of batch 28; got log keys: ['outputs']
# ...Predicting: start of batch 29; got log keys: []
# ...Predicting: end of batch 29; got log keys: ['outputs']
# ...Predicting: start of batch 30; got log keys: []
# ...Predicting: end of batch 30; got log keys: ['outputs']
# ...Predicting: start of batch 31; got log keys: []
# ...Predicting: end of batch 31; got log keys: ['outputs']
# ...Predicting: start of batch 32; got log keys: []
# ...Predicting: end of batch 32; got log keys: ['outputs']
# ...Predicting: start of batch 33; got log keys: []
# ...Predicting: end of batch 33; got log keys: ['outputs']
# ...Predicting: start of batch 34; got log keys: []
# ...Predicting: end of batch 34; got log keys: ['outputs']
# ...Predicting: start of batch 35; got log keys: []
# ...Predicting: end of batch 35; got log keys: ['outputs']
# ...Predicting: start of batch 36; got log keys: []
# ...Predicting: end of batch 36; got log keys: ['outputs']
# ...Predicting: start of batch 37; got log keys: []
# ...Predicting: end of batch 37; got log keys: ['outputs']
# ...Predicting: start of batch 38; got log keys: []
# ...Predicting: end of batch 38; got log keys: ['outputs']
# ...Predicting: start of batch 39; got log keys: []
# ...Predicting: end of batch 39; got log keys: ['outputs']
# ...Predicting: start of batch 40; got log keys: []
# ...Predicting: end of batch 40; got log keys: ['outputs']
# ...Predicting: start of batch 41; got log keys: []
# ...Predicting: end of batch 41; got log keys: ['outputs']
# ...Predicting: start of batch 42; got log keys: []
# ...Predicting: end of batch 42; got log keys: ['outputs']
# ...Predicting: start of batch 43; got log keys: []
# ...Predicting: end of batch 43; got log keys: ['outputs']
# ...Predicting: start of batch 44; got log keys: []
# ...Predicting: end of batch 44; got log keys: ['outputs']
# ...Predicting: start of batch 45; got log keys: []
# ...Predicting: end of batch 45; got log keys: ['outputs']
# ...Predicting: start of batch 46; got log keys: []
# ...Predicting: end of batch 46; got log keys: ['outputs']
# ...Predicting: start of batch 47; got log keys: []
# ...Predicting: end of batch 47; got log keys: ['outputs']
# ...Predicting: start of batch 48; got log keys: []
# ...Predicting: end of batch 48; got log keys: ['outputs']
# ...Predicting: start of batch 49; got log keys: []
# ...Predicting: end of batch 49; got log keys: ['outputs']
# ...Predicting: start of batch 50; got log keys: []
# ...Predicting: end of batch 50; got log keys: ['outputs']
# ...Predicting: start of batch 51; got log keys: []
# ...Predicting: end of batch 51; got log keys: ['outputs']
# ...Predicting: start of batch 52; got log keys: []
# ...Predicting: end of batch 52; got log keys: ['outputs']
# ...Predicting: start of batch 53; got log keys: []
# ...Predicting: end of batch 53; got log keys: ['outputs']
# ...Predicting: start of batch 54; got log keys: []
# ...Predicting: end of batch 54; got log keys: ['outputs']
# ...Predicting: start of batch 55; got log keys: []
# ...Predicting: end of batch 55; got log keys: ['outputs']
# ...Predicting: start of batch 56; got log keys: []
# ...Predicting: end of batch 56; got log keys: ['outputs']
# ...Predicting: start of batch 57; got log keys: []
# ...Predicting: end of batch 57; got log keys: ['outputs']
# ...Predicting: start of batch 58; got log keys: []
# ...Predicting: end of batch 58; got log keys: ['outputs']
# ...Predicting: start of batch 59; got log keys: []
# ...Predicting: end of batch 59; got log keys: ['outputs']
# ...Predicting: start of batch 60; got log keys: []
# ...Predicting: end of batch 60; got log keys: ['outputs']
# ...Predicting: start of batch 61; got log keys: []
# ...Predicting: end of batch 61; got log keys: ['outputs']
# ...Predicting: start of batch 62; got log keys: []
# ...Predicting: end of batch 62; got log keys: ['outputs']
# ...Predicting: start of batch 63; got log keys: []
# ...Predicting: end of batch 63; got log keys: ['outputs']
# ...Predicting: start of batch 64; got log keys: []
# ...Predicting: end of batch 64; got log keys: ['outputs']
# ...Predicting: start of batch 65; got log keys: []
# ...Predicting: end of batch 65; got log keys: ['outputs']
# ...Predicting: start of batch 66; got log keys: []
# ...Predicting: end of batch 66; got log keys: ['outputs']
# ...Predicting: start of batch 67; got log keys: []
# ...Predicting: end of batch 67; got log keys: ['outputs']
# ...Predicting: start of batch 68; got log keys: []
# ...Predicting: end of batch 68; got log keys: ['outputs']
# ...Predicting: start of batch 69; got log keys: []
# ...Predicting: end of batch 69; got log keys: ['outputs']
# ...Predicting: start of batch 70; got log keys: []
# ...Predicting: end of batch 70; got log keys: ['outputs']
# ...Predicting: start of batch 71; got log keys: []
# ...Predicting: end of batch 71; got log keys: ['outputs']
# ...Predicting: start of batch 72; got log keys: []
# ...Predicting: end of batch 72; got log keys: ['outputs']
# ...Predicting: start of batch 73; got log keys: []
# ...Predicting: end of batch 73; got log keys: ['outputs']
# ...Predicting: start of batch 74; got log keys: []
# ...Predicting: end of batch 74; got log keys: ['outputs']
# ...Predicting: start of batch 75; got log keys: []
# ...Predicting: end of batch 75; got log keys: ['outputs']
# ...Predicting: start of batch 76; got log keys: []
# ...Predicting: end of batch 76; got log keys: ['outputs']
# ...Predicting: start of batch 77; got log keys: []
# ...Predicting: end of batch 77; got log keys: ['outputs']
# ...Predicting: start of batch 78; got log keys: []
# ...Predicting: end of batch 78; got log keys: ['outputs']
# ...Predicting: start of batch 79; got log keys: []
# ...Predicting: end of batch 79; got log keys: ['outputs']
# ...Predicting: start of batch 80; got log keys: []
# ...Predicting: end of batch 80; got log keys: ['outputs']
# ...Predicting: start of batch 81; got log keys: []
# ...Predicting: end of batch 81; got log keys: ['outputs']
# ...Predicting: start of batch 82; got log keys: []
# ...Predicting: end of batch 82; got log keys: ['outputs']
# ...Predicting: start of batch 83; got log keys: []
# ...Predicting: end of batch 83; got log keys: ['outputs']
# ...Predicting: start of batch 84; got log keys: []
# ...Predicting: end of batch 84; got log keys: ['outputs']
# ...Predicting: start of batch 85; got log keys: []
# ...Predicting: end of batch 85; got log keys: ['outputs']
# ...Predicting: start of batch 86; got log keys: []
# ...Predicting: end of batch 86; got log keys: ['outputs']
# ...Predicting: start of batch 87; got log keys: []
# ...Predicting: end of batch 87; got log keys: ['outputs']
# ...Predicting: start of batch 88; got log keys: []
# ...Predicting: end of batch 88; got log keys: ['outputs']
# ...Predicting: start of batch 89; got log keys: []
# ...Predicting: end of batch 89; got log keys: ['outputs']
# ...Predicting: start of batch 90; got log keys: []
# ...Predicting: end of batch 90; got log keys: ['outputs']
# ...Predicting: start of batch 91; got log keys: []
# ...Predicting: end of batch 91; got log keys: ['outputs']
# ...Predicting: start of batch 92; got log keys: []
# ...Predicting: end of batch 92; got log keys: ['outputs']
# ...Predicting: start of batch 93; got log keys: []
# ...Predicting: end of batch 93; got log keys: ['outputs']
# ...Predicting: start of batch 94; got log keys: []
# ...Predicting: end of batch 94; got log keys: ['outputs']
# ...Predicting: start of batch 95; got log keys: []
# ...Predicting: end of batch 95; got log keys: ['outputs']
# ...Predicting: start of batch 96; got log keys: []
# ...Predicting: end of batch 96; got log keys: ['outputs']
# ...Predicting: start of batch 97; got log keys: []
# ...Predicting: end of batch 97; got log keys: ['outputs']
# ...Predicting: start of batch 98; got log keys: []
# ...Predicting: end of batch 98; got log keys: ['outputs']
# ...Predicting: start of batch 99; got log keys: []
# ...Predicting: end of batch 99; got log keys: ['outputs']
# ...Predicting: start of batch 100; got log keys: []
# ...Predicting: end of batch 100; got log keys: ['outputs']
# ...Predicting: start of batch 101; got log keys: []
# ...Predicting: end of batch 101; got log keys: ['outputs']
# ...Predicting: start of batch 102; got log keys: []
# ...Predicting: end of batch 102; got log keys: ['outputs']
# ...Predicting: start of batch 103; got log keys: []
# ...Predicting: end of batch 103; got log keys: ['outputs']
# ...Predicting: start of batch 104; got log keys: []
# ...Predicting: end of batch 104; got log keys: ['outputs']
# ...Predicting: start of batch 105; got log keys: []
# ...Predicting: end of batch 105; got log keys: ['outputs']
# ...Predicting: start of batch 106; got log keys: []
# ...Predicting: end of batch 106; got log keys: ['outputs']
# ...Predicting: start of batch 107; got log keys: []
# ...Predicting: end of batch 107; got log keys: ['outputs']
# ...Predicting: start of batch 108; got log keys: []
# ...Predicting: end of batch 108; got log keys: ['outputs']
# ...Predicting: start of batch 109; got log keys: []
# ...Predicting: end of batch 109; got log keys: ['outputs']
# ...Predicting: start of batch 110; got log keys: []
# ...Predicting: end of batch 110; got log keys: ['outputs']
# ...Predicting: start of batch 111; got log keys: []
# ...Predicting: end of batch 111; got log keys: ['outputs']
# ...Predicting: start of batch 112; got log keys: []
# ...Predicting: end of batch 112; got log keys: ['outputs']
# ...Predicting: start of batch 113; got log keys: []
# ...Predicting: end of batch 113; got log keys: ['outputs']
# ...Predicting: start of batch 114; got log keys: []
# ...Predicting: end of batch 114; got log keys: ['outputs']
# ...Predicting: start of batch 115; got log keys: []
# ...Predicting: end of batch 115; got log keys: ['outputs']
# ...Predicting: start of batch 116; got log keys: []
# ...Predicting: end of batch 116; got log keys: ['outputs']
# ...Predicting: start of batch 117; got log keys: []
# ...Predicting: end of batch 117; got log keys: ['outputs']
# ...Predicting: start of batch 118; got log keys: []
# ...Predicting: end of batch 118; got log keys: ['outputs']
# ...Predicting: start of batch 119; got log keys: []
# ...Predicting: end of batch 119; got log keys: ['outputs']
# ...Predicting: start of batch 120; got log keys: []
# ...Predicting: end of batch 120; got log keys: ['outputs']
# ...Predicting: start of batch 121; got log keys: []
# ...Predicting: end of batch 121; got log keys: ['outputs']
# ...Predicting: start of batch 122; got log keys: []
# ...Predicting: end of batch 122; got log keys: ['outputs']
# ...Predicting: start of batch 123; got log keys: []
# ...Predicting: end of batch 123; got log keys: ['outputs']
# ...Predicting: start of batch 124; got log keys: []
# ...Predicting: end of batch 124; got log keys: ['outputs']
# ...Predicting: start of batch 125; got log keys: []
# ...Predicting: end of batch 125; got log keys: ['outputs']
# ...Predicting: start of batch 126; got log keys: []
# ...Predicting: end of batch 126; got log keys: ['outputs']
# ...Predicting: start of batch 127; got log keys: []
# ...Predicting: end of batch 127; got log keys: ['outputs']
# ...Predicting: start of batch 128; got log keys: []
# ...Predicting: end of batch 128; got log keys: ['outputs']
# ...Predicting: start of batch 129; got log keys: []
# ...Predicting: end of batch 129; got log keys: ['outputs']
# ...Predicting: start of batch 130; got log keys: []
# ...Predicting: end of batch 130; got log keys: ['outputs']
# ...Predicting: start of batch 131; got log keys: []
# ...Predicting: end of batch 131; got log keys: ['outputs']
# ...Predicting: start of batch 132; got log keys: []
# ...Predicting: end of batch 132; got log keys: ['outputs']
# ...Predicting: start of batch 133; got log keys: []
# ...Predicting: end of batch 133; got log keys: ['outputs']
# ...Predicting: start of batch 134; got log keys: []
# ...Predicting: end of batch 134; got log keys: ['outputs']
# ...Predicting: start of batch 135; got log keys: []
# ...Predicting: end of batch 135; got log keys: ['outputs']
# ...Predicting: start of batch 136; got log keys: []
# ...Predicting: end of batch 136; got log keys: ['outputs']
# ...Predicting: start of batch 137; got log keys: []
# ...Predicting: end of batch 137; got log keys: ['outputs']
# ...Predicting: start of batch 138; got log keys: []
# ...Predicting: end of batch 138; got log keys: ['outputs']
# ...Predicting: start of batch 139; got log keys: []
# ...Predicting: end of batch 139; got log keys: ['outputs']
# ...Predicting: start of batch 140; got log keys: []
# ...Predicting: end of batch 140; got log keys: ['outputs']
# ...Predicting: start of batch 141; got log keys: []
# ...Predicting: end of batch 141; got log keys: ['outputs']
# ...Predicting: start of batch 142; got log keys: []
# ...Predicting: end of batch 142; got log keys: ['outputs']
# ...Predicting: start of batch 143; got log keys: []
# ...Predicting: end of batch 143; got log keys: ['outputs']
# ...Predicting: start of batch 144; got log keys: []
# ...Predicting: end of batch 144; got log keys: ['outputs']
# ...Predicting: start of batch 145; got log keys: []
# ...Predicting: end of batch 145; got log keys: ['outputs']
# ...Predicting: start of batch 146; got log keys: []
# ...Predicting: end of batch 146; got log keys: ['outputs']
# ...Predicting: start of batch 147; got log keys: []
# ...Predicting: end of batch 147; got log keys: ['outputs']
# ...Predicting: start of batch 148; got log keys: []
# ...Predicting: end of batch 148; got log keys: ['outputs']
# ...Predicting: start of batch 149; got log keys: []
# ...Predicting: end of batch 149; got log keys: ['outputs']
# ...Predicting: start of batch 150; got log keys: []
# ...Predicting: end of batch 150; got log keys: ['outputs']
# ...Predicting: start of batch 151; got log keys: []
# ...Predicting: end of batch 151; got log keys: ['outputs']
# ...Predicting: start of batch 152; got log keys: []
# ...Predicting: end of batch 152; got log keys: ['outputs']
# ...Predicting: start of batch 153; got log keys: []
# ...Predicting: end of batch 153; got log keys: ['outputs']
# ...Predicting: start of batch 154; got log keys: []
# ...Predicting: end of batch 154; got log keys: ['outputs']
# ...Predicting: start of batch 155; got log keys: []
# ...Predicting: end of batch 155; got log keys: ['outputs']
# ...Predicting: start of batch 156; got log keys: []
# ...Predicting: end of batch 156; got log keys: ['outputs']
# ...Predicting: start of batch 157; got log keys: []
# ...Predicting: end of batch 157; got log keys: ['outputs']
# ...Predicting: start of batch 158; got log keys: []
# ...Predicting: end of batch 158; got log keys: ['outputs']
# ...Predicting: start of batch 159; got log keys: []
# ...Predicting: end of batch 159; got log keys: ['outputs']
# ...Predicting: start of batch 160; got log keys: []
# ...Predicting: end of batch 160; got log keys: ['outputs']
# ...Predicting: start of batch 161; got log keys: []
# ...Predicting: end of batch 161; got log keys: ['outputs']
# ...Predicting: start of batch 162; got log keys: []
# ...Predicting: end of batch 162; got log keys: ['outputs']
# ...Predicting: start of batch 163; got log keys: []
# ...Predicting: end of batch 163; got log keys: ['outputs']
# ...Predicting: start of batch 164; got log keys: []
# ...Predicting: end of batch 164; got log keys: ['outputs']
# ...Predicting: start of batch 165; got log keys: []
# ...Predicting: end of batch 165; got log keys: ['outputs']
# ...Predicting: start of batch 166; got log keys: []
# ...Predicting: end of batch 166; got log keys: ['outputs']
# ...Predicting: start of batch 167; got log keys: []
# ...Predicting: end of batch 167; got log keys: ['outputs']
# ...Predicting: start of batch 168; got log keys: []
# ...Predicting: end of batch 168; got log keys: ['outputs']
# ...Predicting: start of batch 169; got log keys: []
# ...Predicting: end of batch 169; got log keys: ['outputs']
# ...Predicting: start of batch 170; got log keys: []
# ...Predicting: end of batch 170; got log keys: ['outputs']
# ...Predicting: start of batch 171; got log keys: []
# ...Predicting: end of batch 171; got log keys: ['outputs']
# ...Predicting: start of batch 172; got log keys: []
# ...Predicting: end of batch 172; got log keys: ['outputs']
# ...Predicting: start of batch 173; got log keys: []
# ...Predicting: end of batch 173; got log keys: ['outputs']
# ...Predicting: start of batch 174; got log keys: []
# ...Predicting: end of batch 174; got log keys: ['outputs']
# ...Predicting: start of batch 175; got log keys: []
# ...Predicting: end of batch 175; got log keys: ['outputs']
# ...Predicting: start of batch 176; got log keys: []
# ...Predicting: end of batch 176; got log keys: ['outputs']
# ...Predicting: start of batch 177; got log keys: []
# ...Predicting: end of batch 177; got log keys: ['outputs']
# ...Predicting: start of batch 178; got log keys: []
# ...Predicting: end of batch 178; got log keys: ['outputs']
# ...Predicting: start of batch 179; got log keys: []
# ...Predicting: end of batch 179; got log keys: ['outputs']
# ...Predicting: start of batch 180; got log keys: []
# ...Predicting: end of batch 180; got log keys: ['outputs']
# ...Predicting: start of batch 181; got log keys: []
# ...Predicting: end of batch 181; got log keys: ['outputs']
# ...Predicting: start of batch 182; got log keys: []
# ...Predicting: end of batch 182; got log keys: ['outputs']
# ...Predicting: start of batch 183; got log keys: []
# ...Predicting: end of batch 183; got log keys: ['outputs']
# ...Predicting: start of batch 184; got log keys: []
# ...Predicting: end of batch 184; got log keys: ['outputs']
# ...Predicting: start of batch 185; got log keys: []
# ...Predicting: end of batch 185; got log keys: ['outputs']
# ...Predicting: start of batch 186; got log keys: []
# ...Predicting: end of batch 186; got log keys: ['outputs']
# ...Predicting: start of batch 187; got log keys: []
# ...Predicting: end of batch 187; got log keys: ['outputs']
# ...Predicting: start of batch 188; got log keys: []
# ...Predicting: end of batch 188; got log keys: ['outputs']
# ...Predicting: start of batch 189; got log keys: []
# ...Predicting: end of batch 189; got log keys: ['outputs']
# ...Predicting: start of batch 190; got log keys: []
# ...Predicting: end of batch 190; got log keys: ['outputs']
# ...Predicting: start of batch 191; got log keys: []
# ...Predicting: end of batch 191; got log keys: ['outputs']
# ...Predicting: start of batch 192; got log keys: []
# ...Predicting: end of batch 192; got log keys: ['outputs']
# ...Predicting: start of batch 193; got log keys: []
# ...Predicting: end of batch 193; got log keys: ['outputs']
# ...Predicting: start of batch 194; got log keys: []
# ...Predicting: end of batch 194; got log keys: ['outputs']
# ...Predicting: start of batch 195; got log keys: []
# ...Predicting: end of batch 195; got log keys: ['outputs']
# ...Predicting: start of batch 196; got log keys: []
# ...Predicting: end of batch 196; got log keys: ['outputs']
# ...Predicting: start of batch 197; got log keys: []
# ...Predicting: end of batch 197; got log keys: ['outputs']
# ...Predicting: start of batch 198; got log keys: []
# ...Predicting: end of batch 198; got log keys: ['outputs']
# ...Predicting: start of batch 199; got log keys: []
# ...Predicting: end of batch 199; got log keys: ['outputs']
# ...Predicting: start of batch 200; got log keys: []
# ...Predicting: end of batch 200; got log keys: ['outputs']
# ...Predicting: start of batch 201; got log keys: []
# ...Predicting: end of batch 201; got log keys: ['outputs']
# ...Predicting: start of batch 202; got log keys: []
# ...Predicting: end of batch 202; got log keys: ['outputs']
# ...Predicting: start of batch 203; got log keys: []
# ...Predicting: end of batch 203; got log keys: ['outputs']
# ...Predicting: start of batch 204; got log keys: []
# ...Predicting: end of batch 204; got log keys: ['outputs']
# ...Predicting: start of batch 205; got log keys: []
# ...Predicting: end of batch 205; got log keys: ['outputs']
# ...Predicting: start of batch 206; got log keys: []
# ...Predicting: end of batch 206; got log keys: ['outputs']
# ...Predicting: start of batch 207; got log keys: []
# ...Predicting: end of batch 207; got log keys: ['outputs']
# ...Predicting: start of batch 208; got log keys: []
# ...Predicting: end of batch 208; got log keys: ['outputs']
# ...Predicting: start of batch 209; got log keys: []
# ...Predicting: end of batch 209; got log keys: ['outputs']
# ...Predicting: start of batch 210; got log keys: []
# ...Predicting: end of batch 210; got log keys: ['outputs']
# ...Predicting: start of batch 211; got log keys: []
# ...Predicting: end of batch 211; got log keys: ['outputs']
# ...Predicting: start of batch 212; got log keys: []
# ...Predicting: end of batch 212; got log keys: ['outputs']
# ...Predicting: start of batch 213; got log keys: []
# ...Predicting: end of batch 213; got log keys: ['outputs']
# ...Predicting: start of batch 214; got log keys: []
# ...Predicting: end of batch 214; got log keys: ['outputs']
# ...Predicting: start of batch 215; got log keys: []
# ...Predicting: end of batch 215; got log keys: ['outputs']
# ...Predicting: start of batch 216; got log keys: []
# ...Predicting: end of batch 216; got log keys: ['outputs']
# ...Predicting: start of batch 217; got log keys: []
# ...Predicting: end of batch 217; got log keys: ['outputs']
# ...Predicting: start of batch 218; got log keys: []
# ...Predicting: end of batch 218; got log keys: ['outputs']
# ...Predicting: start of batch 219; got log keys: []
# ...Predicting: end of batch 219; got log keys: ['outputs']
# ...Predicting: start of batch 220; got log keys: []
# ...Predicting: end of batch 220; got log keys: ['outputs']
# ...Predicting: start of batch 221; got log keys: []
# ...Predicting: end of batch 221; got log keys: ['outputs']
# ...Predicting: start of batch 222; got log keys: []
# ...Predicting: end of batch 222; got log keys: ['outputs']
# ...Predicting: start of batch 223; got log keys: []
# ...Predicting: end of batch 223; got log keys: ['outputs']
# ...Predicting: start of batch 224; got log keys: []
# ...Predicting: end of batch 224; got log keys: ['outputs']
# ...Predicting: start of batch 225; got log keys: []
# ...Predicting: end of batch 225; got log keys: ['outputs']
# ...Predicting: start of batch 226; got log keys: []
# ...Predicting: end of batch 226; got log keys: ['outputs']
# ...Predicting: start of batch 227; got log keys: []
# ...Predicting: end of batch 227; got log keys: ['outputs']
# ...Predicting: start of batch 228; got log keys: []
# ...Predicting: end of batch 228; got log keys: ['outputs']
# ...Predicting: start of batch 229; got log keys: []
# ...Predicting: end of batch 229; got log keys: ['outputs']
# ...Predicting: start of batch 230; got log keys: []
# ...Predicting: end of batch 230; got log keys: ['outputs']
# ...Predicting: start of batch 231; got log keys: []
# ...Predicting: end of batch 231; got log keys: ['outputs']
# ...Predicting: start of batch 232; got log keys: []
# ...Predicting: end of batch 232; got log keys: ['outputs']
# ...Predicting: start of batch 233; got log keys: []
# ...Predicting: end of batch 233; got log keys: ['outputs']
# ...Predicting: start of batch 234; got log keys: []
# ...Predicting: end of batch 234; got log keys: ['outputs']
# ...Predicting: start of batch 235; got log keys: []
# ...Predicting: end of batch 235; got log keys: ['outputs']
# ...Predicting: start of batch 236; got log keys: []
# ...Predicting: end of batch 236; got log keys: ['outputs']
# ...Predicting: start of batch 237; got log keys: []
# ...Predicting: end of batch 237; got log keys: ['outputs']
# ...Predicting: start of batch 238; got log keys: []
# ...Predicting: end of batch 238; got log keys: ['outputs']
# ...Predicting: start of batch 239; got log keys: []
# ...Predicting: end of batch 239; got log keys: ['outputs']
# ...Predicting: start of batch 240; got log keys: []
# ...Predicting: end of batch 240; got log keys: ['outputs']
# ...Predicting: start of batch 241; got log keys: []
# ...Predicting: end of batch 241; got log keys: ['outputs']
# ...Predicting: start of batch 242; got log keys: []
# ...Predicting: end of batch 242; got log keys: ['outputs']
# ...Predicting: start of batch 243; got log keys: []
# ...Predicting: end of batch 243; got log keys: ['outputs']
# ...Predicting: start of batch 244; got log keys: []
# ...Predicting: end of batch 244; got log keys: ['outputs']
# ...Predicting: start of batch 245; got log keys: []
# ...Predicting: end of batch 245; got log keys: ['outputs']
# ...Predicting: start of batch 246; got log keys: []
# ...Predicting: end of batch 246; got log keys: ['outputs']
# ...Predicting: start of batch 247; got log keys: []
# ...Predicting: end of batch 247; got log keys: ['outputs']
# ...Predicting: start of batch 248; got log keys: []
# ...Predicting: end of batch 248; got log keys: ['outputs']
# ...Predicting: start of batch 249; got log keys: []
# ...Predicting: end of batch 249; got log keys: ['outputs']
# ...Predicting: start of batch 250; got log keys: []
# ...Predicting: end of batch 250; got log keys: ['outputs']
# ...Predicting: start of batch 251; got log keys: []
# ...Predicting: end of batch 251; got log keys: ['outputs']
# ...Predicting: start of batch 252; got log keys: []
# ...Predicting: end of batch 252; got log keys: ['outputs']
# ...Predicting: start of batch 253; got log keys: []
# ...Predicting: end of batch 253; got log keys: ['outputs']
# ...Predicting: start of batch 254; got log keys: []
# ...Predicting: end of batch 254; got log keys: ['outputs']
# ...Predicting: start of batch 255; got log keys: []
# ...Predicting: end of batch 255; got log keys: ['outputs']
# Stop predicting; got log keys: []

# %% [markdown]
# ### Usage of `logs` dict
# The `logs` dict contains the loss value, and all the metrics at the end of a batch or
# epoch. Example includes the loss and mean absolute error.

# %%
class LossAndErrorPrintingCallback(tf.keras.callbacks.Callback):
    def on_train_batch_end(self, batch, logs=None):
        print(
            "Up to batch {}, the average loss is {:7.2f}.".format(batch, logs["loss"])
        )

    def on_test_batch_end(self, batch, logs=None):
        print(
            "Up to batch {}, the average loss is {:7.2f}.".format(batch, logs["loss"])
        )

    def on_epoch_end(self, epoch, logs=None):
        print(
            "The average loss for epoch {} is {:7.2f} "
            "and accuracy is {:7.2f}.".format(
                epoch, logs["loss"], logs["accuracy"]
            )
        )

# %%
model.fit(
    train_batches,
    epochs=2,
    verbose=0,
    callbacks=[LossAndErrorPrintingCallback()],
)
# Out:
# Up to batch 0, the average loss is    0.68.
# Up to batch 1, the average loss is    0.65.
# Up to batch 2, the average loss is    0.64.
# Up to batch 3, the average loss is    0.63.
# Up to batch 4, the average loss is    0.63.
# Up to batch 5, the average loss is    0.62.
# Up to batch 6, the average loss is    0.62.
# Up to batch 7, the average loss is    0.62.
# Up to batch 8, the average loss is    0.61.
# Up to batch 9, the average loss is    0.61.
# Up to batch 10, the average loss is    0.61.
# Up to batch 11, the average loss is    0.61.
# Up to batch 12, the average loss is    0.61.
# Up to batch 13, the average loss is    0.61.
# Up to batch 14, the average loss is    0.61.
# Up to batch 15, the average loss is    0.60.
# Up to batch 16, the average loss is    0.60.
# Up to batch 17, the average loss is    0.60.
# Up to batch 18, the average loss is    0.60.
# Up to batch 19, the average loss is    0.60.
# Up to batch 20, the average loss is    0.60.
# Up to batch 21, the average loss is    0.60.
# Up to batch 22, the average loss is    0.60.
# Up to batch 23, the average loss is    0.60.
# Up to batch 24, the average loss is    0.60.
# Up to batch 25, the average loss is    0.60.
# The average loss for epoch 0 is    0.60 and accuracy is    0.76.
# Up to batch 0, the average loss is    0.61.
# Up to batch 1, the average loss is    0.57.
# Up to batch 2, the average loss is    0.56.
# Up to batch 3, the average loss is    0.57.
# Up to batch 4, the average loss is    0.56.
# Up to batch 5, the average loss is    0.56.
# Up to batch 6, the average loss is    0.56.
# Up to batch 7, the average loss is    0.56.
# Up to batch 8, the average loss is    0.56.
# Up to batch 9, the average loss is    0.55.
# Up to batch 10, the average loss is    0.55.
# Up to batch 11, the average loss is    0.55.
# Up to batch 12, the average loss is    0.54.
# Up to batch 13, the average loss is    0.54.
# Up to batch 14, the average loss is    0.54.
# Up to batch 15, the average loss is    0.54.
# Up to batch 16, the average loss is    0.53.
# Up to batch 17, the average loss is    0.53.
# Up to batch 18, the average loss is    0.53.
# Up to batch 19, the average loss is    0.54.
# Up to batch 20, the average loss is    0.54.
# Up to batch 21, the average loss is    0.53.
# Up to batch 22, the average loss is    0.53.
# Up to batch 23, the average loss is    0.53.
# Up to batch 24, the average loss is    0.53.
# Up to batch 25, the average loss is    0.53.
# The average loss for epoch 1 is    0.53 and accuracy is    0.79.

# %%
res = model.evaluate(
    test_batches,
    verbose=0,
    callbacks=[LossAndErrorPrintingCallback()],
)
# Out:
# Up to batch 0, the average loss is    1.32.
# Up to batch 1, the average loss is    1.05.
# Up to batch 2, the average loss is    1.14.
# Up to batch 3, the average loss is    0.90.
# Up to batch 4, the average loss is    0.76.
# Up to batch 5, the average loss is    0.85.
# Up to batch 6, the average loss is    0.86.
# Up to batch 7, the average loss is    0.78.
# Up to batch 8, the average loss is    0.83.
# Up to batch 9, the average loss is    0.77.
# Up to batch 10, the average loss is    0.77.
# Up to batch 11, the average loss is    0.72.
# Up to batch 12, the average loss is    0.68.
# Up to batch 13, the average loss is    0.68.
# Up to batch 14, the average loss is    0.65.
# Up to batch 15, the average loss is    0.70.
# Up to batch 16, the average loss is    0.72.
# Up to batch 17, the average loss is    0.69.
# Up to batch 18, the average loss is    0.72.
# Up to batch 19, the average loss is    0.69.
# Up to batch 20, the average loss is    0.71.
# Up to batch 21, the average loss is    0.69.
# Up to batch 22, the average loss is    0.68.
# Up to batch 23, the average loss is    0.70.
# Up to batch 24, the average loss is    0.71.
# Up to batch 25, the average loss is    0.75.
# Up to batch 26, the average loss is    0.72.
# Up to batch 27, the average loss is    0.75.
# Up to batch 28, the average loss is    0.73.
# Up to batch 29, the average loss is    0.71.
# Up to batch 30, the average loss is    0.70.
# Up to batch 31, the average loss is    0.68.
# Up to batch 32, the average loss is    0.67.
# Up to batch 33, the average loss is    0.70.
# Up to batch 34, the average loss is    0.68.
# Up to batch 35, the average loss is    0.70.
# Up to batch 36, the average loss is    0.71.
# Up to batch 37, the average loss is    0.69.
# Up to batch 38, the average loss is    0.71.
# Up to batch 39, the average loss is    0.70.
# Up to batch 40, the average loss is    0.72.
# Up to batch 41, the average loss is    0.73.
# Up to batch 42, the average loss is    0.71.
# Up to batch 43, the average loss is    0.70.
# Up to batch 44, the average loss is    0.69.
# Up to batch 45, the average loss is    0.70.
# Up to batch 46, the average loss is    0.71.
# Up to batch 47, the average loss is    0.70.
# Up to batch 48, the average loss is    0.71.
# Up to batch 49, the average loss is    0.71.
# Up to batch 50, the average loss is    0.70.
# Up to batch 51, the average loss is    0.69.
# Up to batch 52, the average loss is    0.68.
# Up to batch 53, the average loss is    0.67.
# Up to batch 54, the average loss is    0.68.
# Up to batch 55, the average loss is    0.68.
# Up to batch 56, the average loss is    0.69.
# Up to batch 57, the average loss is    0.68.
# Up to batch 58, the average loss is    0.67.
# Up to batch 59, the average loss is    0.66.
# Up to batch 60, the average loss is    0.65.
# Up to batch 61, the average loss is    0.65.
# Up to batch 62, the average loss is    0.64.
# Up to batch 63, the average loss is    0.63.
# Up to batch 64, the average loss is    0.62.
# Up to batch 65, the average loss is    0.64.
# Up to batch 66, the average loss is    0.64.
# Up to batch 67, the average loss is    0.63.
# Up to batch 68, the average loss is    0.64.
# Up to batch 69, the average loss is    0.65.
# Up to batch 70, the average loss is    0.64.
# Up to batch 71, the average loss is    0.63.
# Up to batch 72, the average loss is    0.63.
# Up to batch 73, the average loss is    0.63.
# Up to batch 74, the average loss is    0.63.
# Up to batch 75, the average loss is    0.65.
# Up to batch 76, the average loss is    0.64.
# Up to batch 77, the average loss is    0.65.
# Up to batch 78, the average loss is    0.66.
# Up to batch 79, the average loss is    0.66.
# Up to batch 80, the average loss is    0.65.
# Up to batch 81, the average loss is    0.66.
# Up to batch 82, the average loss is    0.66.
# Up to batch 83, the average loss is    0.66.
# Up to batch 84, the average loss is    0.65.
# Up to batch 85, the average loss is    0.66.
# Up to batch 86, the average loss is    0.67.
# Up to batch 87, the average loss is    0.67.
# Up to batch 88, the average loss is    0.67.
# Up to batch 89, the average loss is    0.68.
# Up to batch 90, the average loss is    0.68.
# Up to batch 91, the average loss is    0.69.
# Up to batch 92, the average loss is    0.69.
# Up to batch 93, the average loss is    0.69.
# Up to batch 94, the average loss is    0.69.
# Up to batch 95, the average loss is    0.69.
# Up to batch 96, the average loss is    0.69.
# Up to batch 97, the average loss is    0.70.
# Up to batch 98, the average loss is    0.70.
# Up to batch 99, the average loss is    0.69.
# Up to batch 100, the average loss is    0.69.
# Up to batch 101, the average loss is    0.68.
# Up to batch 102, the average loss is    0.68.
# Up to batch 103, the average loss is    0.68.
# Up to batch 104, the average loss is    0.68.
# Up to batch 105, the average loss is    0.68.
# Up to batch 106, the average loss is    0.69.
# Up to batch 107, the average loss is    0.68.
# Up to batch 108, the average loss is    0.68.
# Up to batch 109, the average loss is    0.68.
# Up to batch 110, the average loss is    0.68.
# Up to batch 111, the average loss is    0.67.
# Up to batch 112, the average loss is    0.68.
# Up to batch 113, the average loss is    0.68.
# Up to batch 114, the average loss is    0.69.
# Up to batch 115, the average loss is    0.68.
# Up to batch 116, the average loss is    0.68.
# Up to batch 117, the average loss is    0.67.
# Up to batch 118, the average loss is    0.67.
# Up to batch 119, the average loss is    0.67.
# Up to batch 120, the average loss is    0.67.
# Up to batch 121, the average loss is    0.67.
# Up to batch 122, the average loss is    0.67.
# Up to batch 123, the average loss is    0.68.
# Up to batch 124, the average loss is    0.67.
# Up to batch 125, the average loss is    0.67.
# Up to batch 126, the average loss is    0.67.
# Up to batch 127, the average loss is    0.66.
# Up to batch 128, the average loss is    0.67.
# Up to batch 129, the average loss is    0.66.
# Up to batch 130, the average loss is    0.66.
# Up to batch 131, the average loss is    0.66.
# Up to batch 132, the average loss is    0.66.
# Up to batch 133, the average loss is    0.67.
# Up to batch 134, the average loss is    0.67.
# Up to batch 135, the average loss is    0.67.
# Up to batch 136, the average loss is    0.67.
# Up to batch 137, the average loss is    0.67.
# Up to batch 138, the average loss is    0.66.
# Up to batch 139, the average loss is    0.67.
# Up to batch 140, the average loss is    0.67.
# Up to batch 141, the average loss is    0.66.
# Up to batch 142, the average loss is    0.66.
# Up to batch 143, the average loss is    0.66.
# Up to batch 144, the average loss is    0.66.
# Up to batch 145, the average loss is    0.65.
# Up to batch 146, the average loss is    0.65.
# Up to batch 147, the average loss is    0.66.
# Up to batch 148, the average loss is    0.66.
# Up to batch 149, the average loss is    0.66.
# Up to batch 150, the average loss is    0.66.
# Up to batch 151, the average loss is    0.66.
# Up to batch 152, the average loss is    0.66.
# Up to batch 153, the average loss is    0.67.
# Up to batch 154, the average loss is    0.67.
# Up to batch 155, the average loss is    0.67.
# Up to batch 156, the average loss is    0.67.
# Up to batch 157, the average loss is    0.66.
# Up to batch 158, the average loss is    0.66.
# Up to batch 159, the average loss is    0.66.
# Up to batch 160, the average loss is    0.66.
# Up to batch 161, the average loss is    0.66.
# Up to batch 162, the average loss is    0.66.
# Up to batch 163, the average loss is    0.66.
# Up to batch 164, the average loss is    0.65.
# Up to batch 165, the average loss is    0.65.
# Up to batch 166, the average loss is    0.65.
# Up to batch 167, the average loss is    0.66.
# Up to batch 168, the average loss is    0.65.
# Up to batch 169, the average loss is    0.65.
# Up to batch 170, the average loss is    0.65.
# Up to batch 171, the average loss is    0.65.
# Up to batch 172, the average loss is    0.65.
# Up to batch 173, the average loss is    0.66.
# Up to batch 174, the average loss is    0.65.
# Up to batch 175, the average loss is    0.65.
# Up to batch 176, the average loss is    0.66.
# Up to batch 177, the average loss is    0.66.
# Up to batch 178, the average loss is    0.66.
# Up to batch 179, the average loss is    0.65.
# Up to batch 180, the average loss is    0.65.
# Up to batch 181, the average loss is    0.65.
# Up to batch 182, the average loss is    0.65.
# Up to batch 183, the average loss is    0.65.
# Up to batch 184, the average loss is    0.65.
# Up to batch 185, the average loss is    0.65.
# Up to batch 186, the average loss is    0.65.
# Up to batch 187, the average loss is    0.65.
# Up to batch 188, the average loss is    0.65.
# Up to batch 189, the average loss is    0.65.
# Up to batch 190, the average loss is    0.65.
# Up to batch 191, the average loss is    0.65.
# Up to batch 192, the average loss is    0.65.
# Up to batch 193, the average loss is    0.65.
# Up to batch 194, the average loss is    0.66.
# Up to batch 195, the average loss is    0.65.
# Up to batch 196, the average loss is    0.66.
# Up to batch 197, the average loss is    0.66.
# Up to batch 198, the average loss is    0.66.
# Up to batch 199, the average loss is    0.66.
# Up to batch 200, the average loss is    0.66.
# Up to batch 201, the average loss is    0.66.
# Up to batch 202, the average loss is    0.66.
# Up to batch 203, the average loss is    0.66.
# Up to batch 204, the average loss is    0.66.
# Up to batch 205, the average loss is    0.67.
# Up to batch 206, the average loss is    0.66.
# Up to batch 207, the average loss is    0.66.
# Up to batch 208, the average loss is    0.66.
# Up to batch 209, the average loss is    0.67.
# Up to batch 210, the average loss is    0.67.
# Up to batch 211, the average loss is    0.67.
# Up to batch 212, the average loss is    0.67.
# Up to batch 213, the average loss is    0.67.
# Up to batch 214, the average loss is    0.67.
# Up to batch 215, the average loss is    0.67.
# Up to batch 216, the average loss is    0.67.
# Up to batch 217, the average loss is    0.67.
# Up to batch 218, the average loss is    0.68.
# Up to batch 219, the average loss is    0.67.
# Up to batch 220, the average loss is    0.67.
# Up to batch 221, the average loss is    0.67.
# Up to batch 222, the average loss is    0.68.
# Up to batch 223, the average loss is    0.68.
# Up to batch 224, the average loss is    0.68.
# Up to batch 225, the average loss is    0.67.
# Up to batch 226, the average loss is    0.67.
# Up to batch 227, the average loss is    0.67.
# Up to batch 228, the average loss is    0.67.
# Up to batch 229, the average loss is    0.67.
# Up to batch 230, the average loss is    0.66.
# Up to batch 231, the average loss is    0.67.
# Up to batch 232, the average loss is    0.66.
# Up to batch 233, the average loss is    0.66.
# Up to batch 234, the average loss is    0.66.
# Up to batch 235, the average loss is    0.66.
# Up to batch 236, the average loss is    0.66.
# Up to batch 237, the average loss is    0.66.
# Up to batch 238, the average loss is    0.67.
# Up to batch 239, the average loss is    0.67.
# Up to batch 240, the average loss is    0.66.
# Up to batch 241, the average loss is    0.66.
# Up to batch 242, the average loss is    0.67.
# Up to batch 243, the average loss is    0.67.
# Up to batch 244, the average loss is    0.67.
# Up to batch 245, the average loss is    0.68.
# Up to batch 246, the average loss is    0.68.
# Up to batch 247, the average loss is    0.68.
# Up to batch 248, the average loss is    0.68.
# Up to batch 249, the average loss is    0.67.
# Up to batch 250, the average loss is    0.67.
# Up to batch 251, the average loss is    0.67.
# Up to batch 252, the average loss is    0.67.
# Up to batch 253, the average loss is    0.67.
# Up to batch 254, the average loss is    0.67.
# Up to batch 255, the average loss is    0.67.

# %% [markdown]
# ## Usage of `self.model` attribute
#
# In addition to receiving log information when one of their methods is called,
# callbacks have access to the model associated with the current round of
# training/evaluation/inference: `self.model`.
#
# Here are a few of the things you can do with `self.model` in a callback:
#
# - Set `self.model.stop_training = True` to immediately interrupt training.
# - Mutate hyperparameters of the optimizer (available as `self.model.optimizer`),
# such as `self.model.optimizer.learning_rate`.
# - Save the model at period intervals.
# - Record the output of `model.predict()` on a few test samples at the end of each
# epoch, to use as a sanity check during training.
# - Extract visualizations of intermediate features at the end of each epoch, to monitor
# what the model is learning over time.
# - etc.
#
# Let's see this in action in a couple of examples.

# %% [markdown]
# ### A Callback for Detecting Overfitting
# Let's explore a call back where we measure the ratio between our validation loss and our training loss. If the ratio gets too high, we could have an over-fitting scenario because the validation loss may no longer be decreasing while the training loss continues to decrease, making the ratio of validation loss divided by training loss higher. We should in this case, stop training to avoid overfitting.

# %%
class DetectOverfittingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold=0.7):
        super(DetectOverfittingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        ratio = logs["val_loss"] / logs["loss"]
        print("Epoch: {}, Val/Train loss ratio: {:.2f}".format(epoch, ratio))

        if ratio > self.threshold:
            print("Stopping training...")
            self.model.stop_training = True

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
model.fit(train_batches, 
          epochs=10, 
          validation_data=validation_batches, 
          verbose=0,
          callbacks=[DetectOverfittingCallback()])
# Out:
# Epoch: 0, Val/Train loss ratio: 0.98
# Stopping training...

# %% [markdown]
# See [this deeplearning.ai](https://www.coursera.org/learn/custom-models-layers-loss-functions-with-tensorflow) course for a great example on viusalizing results at the end of each epoch
